# %%
using CSV

# %%
using Statistics

# %%
using DataFrames

# %%
using Plots

# %%
using StatsBase

# %%
df = CSV.read("data.csv")
# Out:
# 18207×89 DataFrame. Omitted printing of 85 columns
# │ Row   │ Column1 │ ID     │ Name               │ Age   │
# │       │ Int64   │ Int64  │ String             │ Int64 │
# ├───────┼─────────┼────────┼────────────────────┼───────┤
# │ 1     │ 0       │ 158023 │ L. Messi           │ 31    │
# │ 2     │ 1       │ 20801  │ Cristiano Ronaldo  │ 33    │
# │ 3     │ 2       │ 190871 │ Neymar Jr          │ 26    │
# │ 4     │ 3       │ 193080 │ De Gea             │ 27    │
# │ 5     │ 4       │ 192985 │ K. De Bruyne       │ 27    │
# │ 6     │ 5       │ 183277 │ E. Hazard          │ 27    │
# │ 7     │ 6       │ 177003 │ L. Modrić          │ 32    │
# │ 8     │ 7       │ 176580 │ L. Suárez          │ 31    │
# │ 9     │ 8       │ 155862 │ Sergio Ramos       │ 32    │
# │ 10    │ 9       │ 200389 │ J. Oblak           │ 25    │
# ⋮
# │ 18197 │ 18196   │ 238477 │ K. Fujikawa        │ 19    │
# │ 18198 │ 18197   │ 246167 │ D. Holland         │ 18    │
# ...

# %%
head(df,5)
# Out:
# ┌ Warning: `head(df::AbstractDataFrame, n::Integer)` is deprecated, use `first(df, n)` instead.
# │   caller = top-level scope at In[7]:1
# └ @ Core In[7]:1
# 5×89 DataFrame. Omitted printing of 85 columns
# │ Row │ Column1 │ ID     │ Name              │ Age   │
# │     │ Int64   │ Int64  │ String            │ Int64 │
# ├─────┼─────────┼────────┼───────────────────┼───────┤
# │ 1   │ 0       │ 158023 │ L. Messi          │ 31    │
# │ 2   │ 1       │ 20801  │ Cristiano Ronaldo │ 33    │
# │ 3   │ 2       │ 190871 │ Neymar Jr         │ 26    │
# │ 4   │ 3       │ 193080 │ De Gea            │ 27    │
# │ 5   │ 4       │ 192985 │ K. De Bruyne      │ 27    │

# %%
tail(df,5)
# Out:
# ┌ Warning: `tail(df::AbstractDataFrame, n::Integer)` is deprecated, use `last(df, n)` instead.
# │   caller = top-level scope at In[8]:1
# └ @ Core In[8]:1
# 5×89 DataFrame. Omitted printing of 85 columns
# │ Row │ Column1 │ ID     │ Name               │ Age   │
# │     │ Int64   │ Int64  │ String             │ Int64 │
# ├─────┼─────────┼────────┼────────────────────┼───────┤
# │ 1   │ 18202   │ 238813 │ J. Lundstram       │ 19    │
# │ 2   │ 18203   │ 243165 │ N. Christoffersson │ 19    │
# │ 3   │ 18204   │ 241638 │ B. Worman          │ 16    │
# │ 4   │ 18205   │ 246268 │ D. Walker-Rice     │ 17    │
# │ 5   │ 18206   │ 246269 │ G. Nugent          │ 16    │

# %%
names(df)
# Out:
# 89-element Array{String,1}:
#  "Column1"
#  "ID"
#  "Name"
#  "Age"
#  "Photo"
#  "Nationality"
#  "Flag"
#  "Overall"
#  "Potential"
#  "Club"
#  "Club Logo"
#  "Value"
#  "Wage"
#  ⋮
#  "Vision"
#  "Penalties"
#  "Composure"
#  "Marking"
#  "StandingTackle"
#  "SlidingTackle"
#  "GKDiving"
#  "GKHandling"
#  "GKKicking"
#  "GKPositioning"
#  "GKReflexes"
#  "Release Clause"

# %%
showall(describe(df))
# Out:
# ┌ Warning: `showall(df::AbstractDataFrame, allcols::Bool = true)` is deprecated, use `show(df, allrows = true, allcols = allcols)` instead.
# │   caller = showall(::DataFrame) at deprecated.jl:66
# └ @ DataFrames .\deprecated.jl:66
# 89×8 DataFrame
# │ Row │ variable                 │ mean     │
# │     │ Symbol                   │ Union…   │
# ├─────┼──────────────────────────┼──────────┤
# │ 1   │ Column1                  │ 9103.0   │
# │ 2   │ ID                       │ 214298.0 │
# │ 3   │ Name                     │          │
# │ 4   │ Age                      │ 25.1222  │
# │ 5   │ Photo                    │          │
# │ 6   │ Nationality              │          │
# │ 7   │ Flag                     │          │
# │ 8   │ Overall                  │ 66.2387  │
# │ 9   │ Potential                │ 71.3073  │
# │ 10  │ Club                     │          │
# │ 11  │ Club Logo                │          │
# │ 12  │ Value                    │          │
# ...

# %%
size(df)
# Out:
# (18207, 89)

# %%
tail(describe(df),5)
# Out:
# ┌ Warning: `tail(df::AbstractDataFrame, n::Integer)` is deprecated, use `last(df, n)` instead.
# │   caller = top-level scope at In[12]:1
# └ @ Core In[12]:1
# 5×8 DataFrame. Omitted printing of 1 columns
# │ Row │ variable       │ mean    │ min   │ median │ max │ nunique │ nmissing │
# │     │ Symbol         │ Union…  │ Any   │ Union… │ Any │ Union…  │ Union…   │
# ├─────┼────────────────┼─────────┼───────┼────────┼─────┼─────────┼──────────┤
# │ 1   │ GKHandling     │ 16.3916 │ 1     │ 11.0   │ 92  │         │ 48       │
# │ 2   │ GKKicking      │ 16.2321 │ 1     │ 11.0   │ 91  │         │ 48       │
# │ 3   │ GKPositioning  │ 16.3889 │ 1     │ 11.0   │ 90  │         │ 48       │
# │ 4   │ GKReflexes     │ 16.7109 │ 1     │ 11.0   │ 94  │         │ 48       │
# │ 5   │ Release Clause │         │ €1.1M │        │ €9M │ 1244    │ 1564     │

# %%
names(df)
# Out:
# 89-element Array{String,1}:
#  "Column1"
#  "ID"
#  "Name"
#  "Age"
#  "Photo"
#  "Nationality"
#  "Flag"
#  "Overall"
#  "Potential"
#  "Club"
#  "Club Logo"
#  "Value"
#  "Wage"
#  ⋮
#  "Vision"
#  "Penalties"
#  "Composure"
#  "Marking"
#  "StandingTackle"
#  "SlidingTackle"
#  "GKDiving"
#  "GKHandling"
#  "GKKicking"
#  "GKPositioning"
#  "GKReflexes"
#  "Release Clause"

# %%
 indian_players=filter(row -> row.Nationality in ["India"], df)
# Out:
# 30×89 DataFrame. Omitted printing of 85 columns
# │ Row │ Column1 │ ID     │ Name            │ Age   │
# │     │ Int64   │ Int64  │ String          │ Int64 │
# ├─────┼─────────┼────────┼─────────────────┼───────┤
# │ 1   │ 8605    │ 190939 │ S. Chhetri      │ 33    │
# │ 2   │ 10011   │ 223763 │ S. Jhingan      │ 24    │
# │ 3   │ 12598   │ 217225 │ J. Lalpekhlua   │ 27    │
# │ 4   │ 12811   │ 225213 │ G. Singh Sandhu │ 26    │
# │ 5   │ 13508   │ 238205 │ A. Edathodika   │ 31    │
# │ 6   │ 14054   │ 231461 │ P. Halder       │ 25    │
# │ 7   │ 14199   │ 228188 │ P. Kotal        │ 24    │
# │ 8   │ 14218   │ 208485 │ L. Ralte        │ 25    │
# │ 9   │ 14705   │ 223764 │ N. Das          │ 24    │
# │ 10  │ 14786   │ 233524 │ U. Singh        │ 22    │
# ⋮
# │ 20  │ 16450   │ 193911 │ S. Paul         │ 31    │
# │ 21  │ 16499   │ 221588 │ A. Mondal       │ 28    │
# │ 22  │ 16539   │ 245167 │ L. Lalruatthara │ 23    │
# │ 23  │ 16793   │ 228192 │ E. Lyngdoh      │ 31    │
# ...

# %%
using Plots
using StatsPlots

# %%
mean(indian_players["Age"])
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[16]:1
# └ @ Core In[16]:1
# 24.933333333333334

# %%
@df indian_players bar(
                :Overall 
    
  )

# %%
 penalties= last(sort!(indian_players,:Penalties),5)
# Out:
# 5×89 DataFrame. Omitted printing of 85 columns
# │ Row │ Column1 │ ID     │ Name          │ Age   │
# │     │ Int64   │ Int64  │ String        │ Int64 │
# ├─────┼─────────┼────────┼───────────────┼───────┤
# │ 1   │ 12598   │ 217225 │ J. Lalpekhlua │ 27    │
# │ 2   │ 17129   │ 228198 │ J. Singh      │ 26    │
# │ 3   │ 14915   │ 228199 │ H. Narzary    │ 24    │
# │ 4   │ 15884   │ 223771 │ B. Singh      │ 31    │
# │ 5   │ 8605    │ 190939 │ S. Chhetri    │ 33    │

# %%
penalties["Penalties"]
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[19]:1
# └ @ Core In[19]:1
# 5-element Array{Union{Missing, Int64},1}:
#  65
#  65
#  66
#  66
#  73

# %%
bar(penalties["Name"],penalties["Penalties"])
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[20]:1
# └ @ Core In[20]:1
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[20]:1
# └ @ Core In[20]:1

# %%
composure= last(sort!(indian_players,:Composure),5)
# Out:
# 5×89 DataFrame. Omitted printing of 85 columns
# │ Row │ Column1 │ ID     │ Name       │ Age   │
# │     │ Int64   │ Int64  │ String     │ Int64 │
# ├─────┼─────────┼────────┼────────────┼───────┤
# │ 1   │ 14054   │ 231461 │ P. Halder  │ 25    │
# │ 2   │ 15652   │ 245170 │ A. Thapa   │ 20    │
# │ 3   │ 16793   │ 228192 │ E. Lyngdoh │ 31    │
# │ 4   │ 10011   │ 223763 │ S. Jhingan │ 24    │
# │ 5   │ 8605    │ 190939 │ S. Chhetri │ 33    │

# %%
bar(composure["Name"],composure["Composure"])
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[22]:1
# └ @ Core In[22]:1
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[22]:1
# └ @ Core In[22]:1

# %%
ballcontrol= last(sort!(indian_players,:BallControl),5)
bar(ballcontrol["Name"],ballcontrol["BallControl"])
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[23]:2
# └ @ Core In[23]:2
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[23]:2
# └ @ Core In[23]:2

# %%
indian_players.Position
# Out:
# 30-element Array{Union{Missing, String},1}:
#  missing
#  "GK"
#  "GK"
#  "GK"
#  missing
#  "CB"
#  "LCB"
#  "CB"
#  "LB"
#  "LB"
#  missing
#  missing
#  "RCB"
#  ⋮
#  "LW"
#  "ST"
#  "CM"
#  "RB"
#  "ST"
#  "LM"
#  "LW"
#  "LCM"
#  "RM"
#  "RS"
#  missing
#  "LS"

# %%
countmap(indian_players.Position)
# Out:
# Dict{Union{Missing, String},Int64} with 17 entries:
#   "RCM"   => 1
#   "CM"    => 1
#   "RB"    => 1
#   "RS"    => 1
#   "LS"    => 1
#   "GK"    => 3
#   "LCB"   => 1
#   "CB"    => 2
#   "RM"    => 1
#   "RCB"   => 1
#   "LCM"   => 1
#   "ST"    => 2
#   "LW"    => 2
#   "CDM"   => 1
#   "LM"    => 1
#   missing => 7
#   "LB"    => 3

# %%
rename!(df, Symbol("Preferred Foot") => :Prefereed_Foot)
# Out:
# 18207×89 DataFrame. Omitted printing of 85 columns
# │ Row   │ Column1 │ ID     │ Name               │ Age   │
# │       │ Int64   │ Int64  │ String             │ Int64 │
# ├───────┼─────────┼────────┼────────────────────┼───────┤
# │ 1     │ 0       │ 158023 │ L. Messi           │ 31    │
# │ 2     │ 1       │ 20801  │ Cristiano Ronaldo  │ 33    │
# │ 3     │ 2       │ 190871 │ Neymar Jr          │ 26    │
# │ 4     │ 3       │ 193080 │ De Gea             │ 27    │
# │ 5     │ 4       │ 192985 │ K. De Bruyne       │ 27    │
# │ 6     │ 5       │ 183277 │ E. Hazard          │ 27    │
# │ 7     │ 6       │ 177003 │ L. Modrić          │ 32    │
# │ 8     │ 7       │ 176580 │ L. Suárez          │ 31    │
# │ 9     │ 8       │ 155862 │ Sergio Ramos       │ 32    │
# │ 10    │ 9       │ 200389 │ J. Oblak           │ 25    │
# ⋮
# │ 18197 │ 18196   │ 238477 │ K. Fujikawa        │ 19    │
# │ 18198 │ 18197   │ 246167 │ D. Holland         │ 18    │
# ...

# %%
rename!(indian_players, Symbol("Preferred Foot") => :Prefereed_Foot)
# Out:
# 30×89 DataFrame. Omitted printing of 85 columns
# │ Row │ Column1 │ ID     │ Name            │ Age   │
# │     │ Int64   │ Int64  │ String          │ Int64 │
# ├─────┼─────────┼────────┼─────────────────┼───────┤
# │ 1   │ 16450   │ 193911 │ S. Paul         │ 31    │
# │ 2   │ 17197   │ 245164 │ V. Kaith        │ 21    │
# │ 3   │ 12811   │ 225213 │ G. Singh Sandhu │ 26    │
# │ 4   │ 15864   │ 223760 │ A. Singh        │ 25    │
# │ 5   │ 17539   │ 234508 │ C. Singh        │ 21    │
# │ 6   │ 15643   │ 245166 │ S. Singh        │ 22    │
# │ 7   │ 13508   │ 238205 │ A. Edathodika   │ 31    │
# │ 8   │ 16499   │ 221588 │ A. Mondal       │ 28    │
# │ 9   │ 16903   │ 245169 │ J. Lalrinzuala  │ 19    │
# │ 10  │ 16135   │ 245165 │ S. Bose         │ 22    │
# ⋮
# │ 20  │ 15884   │ 223771 │ B. Singh        │ 31    │
# │ 21  │ 15855   │ 234507 │ M. Rafique      │ 25    │
# │ 22  │ 14199   │ 228188 │ P. Kotal        │ 24    │
# │ 23  │ 15356   │ 212502 │ R. Singh        │ 28    │
# ...

# %% [markdown]
# <h4>almost 1/3 are left footed

# %%
bar(countmap(indian_players["Prefereed_Foot"]))
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[50]:1
# └ @ Core In[50]:1

# %%
bar(countmap(df["Prefereed_Foot"]))
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[52]:1
# └ @ Core In[52]:1

# %%
bar(countmap(df["Position"]))
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[55]:1
# └ @ Core In[55]:1

# %%
rename!(indian_players, Symbol("Jersey Number") => :Jersey_Number)
rename!(df, Symbol("Jersey Number") => :Jersey_Number)
# Out:
# 18207×89 DataFrame. Omitted printing of 85 columns
# │ Row   │ Column1 │ ID     │ Name               │ Age   │
# │       │ Int64   │ Int64  │ String             │ Int64 │
# ├───────┼─────────┼────────┼────────────────────┼───────┤
# │ 1     │ 0       │ 158023 │ L. Messi           │ 31    │
# │ 2     │ 1       │ 20801  │ Cristiano Ronaldo  │ 33    │
# │ 3     │ 2       │ 190871 │ Neymar Jr          │ 26    │
# │ 4     │ 3       │ 193080 │ De Gea             │ 27    │
# │ 5     │ 4       │ 192985 │ K. De Bruyne       │ 27    │
# │ 6     │ 5       │ 183277 │ E. Hazard          │ 27    │
# │ 7     │ 6       │ 177003 │ L. Modrić          │ 32    │
# │ 8     │ 7       │ 176580 │ L. Suárez          │ 31    │
# │ 9     │ 8       │ 155862 │ Sergio Ramos       │ 32    │
# │ 10    │ 9       │ 200389 │ J. Oblak           │ 25    │
# ⋮
# │ 18197 │ 18196   │ 238477 │ K. Fujikawa        │ 19    │
# │ 18198 │ 18197   │ 246167 │ D. Holland         │ 18    │
# ...

# %% [markdown]
# <h3> Most Common Jersey Number

# %%
findmax(countmap((df["Jersey_Number"])))
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[71]:1
# └ @ Core In[71]:1
# (612, 8)

# %% [markdown]
# <h3> 1 - 23 are the  most Common jerseys

# %%
bar(countmap((df["Jersey_Number"])))
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[75]:1
# └ @ Core In[75]:1

# %%
rename!(indian_players, Symbol("Release Clause") => :release_Clause)
rename!(df, Symbol("Release Clause") => :release_Clause)
# Out:
# 18207×89 DataFrame. Omitted printing of 85 columns
# │ Row   │ Column1 │ ID     │ Name               │ Age   │
# │       │ Int64   │ Int64  │ String             │ Int64 │
# ├───────┼─────────┼────────┼────────────────────┼───────┤
# │ 1     │ 0       │ 158023 │ L. Messi           │ 31    │
# │ 2     │ 1       │ 20801  │ Cristiano Ronaldo  │ 33    │
# │ 3     │ 2       │ 190871 │ Neymar Jr          │ 26    │
# │ 4     │ 3       │ 193080 │ De Gea             │ 27    │
# │ 5     │ 4       │ 192985 │ K. De Bruyne       │ 27    │
# │ 6     │ 5       │ 183277 │ E. Hazard          │ 27    │
# │ 7     │ 6       │ 177003 │ L. Modrić          │ 32    │
# │ 8     │ 7       │ 176580 │ L. Suárez          │ 31    │
# │ 9     │ 8       │ 155862 │ Sergio Ramos       │ 32    │
# │ 10    │ 9       │ 200389 │ J. Oblak           │ 25    │
# ⋮
# │ 18197 │ 18196   │ 238477 │ K. Fujikawa        │ 19    │
# │ 18198 │ 18197   │ 246167 │ D. Holland         │ 18    │
# ...
